# %%
# CANADIAN FLAG


## French Flag
objs = []

#bg = rect(0, 0, 1, 1,[1, 0, 0])

bleu = rect(0, 0, 0.2, 1,[0, 0, 1])
blanc = rect(.2, 0, 0.4, 1,[1,1,1])
rouge = rect(.4, 0, 0.6, 1, [1,0,0]) 


#objs.append(bg)
objs.append(bleu)
objs.append(blanc)
objs.append(rouge)
#objs.append(star(0.8, 0.8, 0.1, 5, [1,1,1]))

display_flag((12,8), objs)# figure size

# %%
import matplotlib.pyplot as plt
import math

div =  input("Amount of stripes: ") 
number_div = int(div)
colored_stripes = []
direction = input("Which direction ?  ") 


objs = []

class Polygon:
    def __init__(self, xlist, ylist, col):
        self.xlist = xlist
        self.ylist = ylist
        self.col = col
        
    def display(self):
        plt.fill(self.xlist, self.ylist, c = self.col)

        
class Polygon:
    def __init__(self):
        self.x = []
        self.y = []
        self.col = []

# TO CREATE RECTANGLES        
def rect(x1, y1, x2, y2, c):
    r = Polygon()
    r.x = [x1, x2, x2, x1]
    r.y = [y1, y1, y2, y2]
    r.col = c 
    return r




# TO DISPLAY FLAG
def display_flag(canvas, objects):# takes canvas + list of objects
    plt.figure(figsize = canvas)
    plt.axis('on')
    for o in objects:
        plt.fill(o.x, o.y, c = o.col)
      

# RGB convertor from Laszlo

def rgb_con(r,g,b):
   rc = 1/255*r
   gc = 1/255*g
   bc = 1/255*b
   c = [rc,gc,bc]
   return c
rgb_con(255,255,255) 



# for i in range(grid_x):
#     for j in range(grid_y):
        
if direction == "vertical":
#VERTICAL
    for i in range(number_div):
#       input_color = [float(input("R value: " )) , float(input("G value: ")),float(input("B value: "))] 
        input_color = rgb_con(float(input("R value: " )) , float(input("G value: ")),float(input("B value: ")))        
        temp_strip = rect(i, 0, i + 1,  1, input_color)
        #print (temp_strip)
        objs.append(temp_strip)  
    
elif direction == "horizontal" :
#HORIZONTAL
    for i in range(number_div):
        input_color =  rgb_con(float(input("R value: " )) , float(input("G value: ")),float(input("B value: ")))
        temp_strip = rect(0, i, 1, i + 1, input_color)
        #print (temp_strip)
        objs.append(temp_strip)

else : 
    pass;


# temp_strip = rect(0, 0, 1, 1, 'red')
# temp_strip2 = rect(0, 1, 1, 2, 'green')
# temp_strip3 = rect(0, 2, 1, 3, 'blue')
# objs.append(temp_strip)
# objs.append(temp_strip2)
# objs.append(temp_strip3)


#objs.append(bg)
#objs.append(temp_strip)
#objs.append(stripe2)
#objs.append(stripe3)

#objs.append(star(0.8, 0.8, 0.1, 5, [1,1,1]))



display_flag((6,4), objs) # figure size
# Out:
# Amount of stripes: 1
# Which direction ?vertical
# R value: 255
# G value: 123
# B value: 41

# %%
import matplotlib.pyplot as plt
import math
import random as r

div =  input("Amount of stripes: ") #"Amount of stripes"
number_div = int(div)
colored_stripes = []
direction = input("Which direction ? Type vertical or horizontal ")
rgb_input = input("Color value input method ? Type random or fixed  ")
# seed = r.seed(123)

objs = []

class Polygon:
    def __init__(self, xlist, ylist, col):
        self.xlist = xlist
        self.ylist = ylist
        self.col = col
        
    def display(self):
        plt.fill(self.xlist, self.ylist, c = self.col)
        
class Polygon:
    def __init__(self):
        self.x = []
        self.y = []
        self.col = []

# TO CREATE RECTANGLES        
def rect(x1, y1, x2, y2, c):
    r = Polygon()
    r.x = [x1, x2, x2, x1]
    r.y = [y1, y1, y2, y2]
    r.col = c 
    return r

# TO DISPLAY FLAG
def display_flag(canvas, objects):# takes canvas + list of objects
    plt.figure(figsize = canvas)
    plt.axis('on')
    for o in objects:
        plt.fill(o.x, o.y, c = o.col)
      

# RGB convertor from Laszlo

def rgb_con(r,g,b):
   rc = 1/255*r
   gc = 1/255*g
   bc = 1/255*b
   c = [rc,gc,bc]
   return c
rgb_con(255,255,255) 




if direction == "vertical" and rgb_input == "random":
#VERTICAL
    for i in range(number_div): 
        input_color = rgb_con(float(r.randint(0,255)) ,float(r.randint(0,255)),float(r.randint(0,255)))        
        temp_strip = rect(i, 0, i + 1,  1, input_color)
        #print (temp_strip)
        objs.append(temp_strip)
elif direction == "vertical" and rgb_input == "fixed":
#VERTICAL
    for i in range(number_div): 
        input_color = rgb_con(float(input("R value: " )) , float(input("G value: ")),float(input("B value: ")))        
        temp_strip = rect(i, 0, i + 1,  1, input_color)
        objs.append(temp_strip)  
        
    
elif direction == "horizontal" and rgb_input == "random" :
#HORIZONTAL
    for i in range(number_div):
        input_color = rgb_con(float(r.randint(0,255)) ,float(r.randint(0,255)),float(r.randint(0,255)))
        temp_strip = rect(0, i, 1, i + 1, input_color)
        objs.append(temp_strip)
elif direction == "horizontal" and rgb_input == "fixed" :
#HORIZONTAL
    for i in range(number_div):
        input_color = rgb_con(float(input("R value: " )) , float(input("G value: ")),float(input("B value: ")))
        temp_strip = rect(0, i, 1, i + 1, input_color)
        objs.append(temp_strip)


else : 
    pass;


# temp_strip = rect(0, 0, 1, 1, 'red')
# temp_strip2 = rect(0, 1, 1, 2, 'green')
# temp_strip3 = rect(0, 2, 1, 3, 'blue')
# objs.append(temp_strip)
# objs.append(temp_strip2)
# objs.append(temp_strip3)


#objs.append(bg)
#objs.append(temp_strip)
#objs.append(stripe2)
#objs.append(stripe3)

#objs.append(star(0.8, 0.8, 0.1, 5, [1,1,1]))



display_flag((20,15), objs) # figure size
# Out:
# Amount of stripes: 150
# Which direction ? Type vertical or horizontal horizontal
# Color value input method ? Type random or fixed  random
