# %%
import matplotlib.pyplot as plt

# %%
class Rect(object):
    def __init__(self, cx, cy, width, height):
        self.cx = cx
        self.cy = cy
        self.width = width
        self.height = height
        w2 = self.width/2.0
        h2 = self.height/2.0
        #list of x and list of y coordinates
        self.x=[self.cx-w2, self.cx+w2, self.cx+w2, self.cx-w2, self.cx-w2]
        self.y = [self.cy-h2, self.cy-h2, self.cy+h2,self.cy+h2,self.cy-h2]
        
        
    def display (self, colorv):
        plt.axis("equal")
        plt.plot(self.x, self.y, c="k", linewidth=1)
        plt.fill(self.x, self.y, c=colorv, linewidth=1)

# %%
# rectangle define : center pt, width and height

r=Rect(1,2,3,4)
r.display(ct)

# %%
rects=[]

for x in range(5):
    for y in range(5):
        r=Rect(x*10, y*10, 8, 8)
        rects.append(r)
for r in rects:
    r.display(ct)

# %%
import random

# %%
rects= []
for x in range(5):
    for y in range(5):
        s=3+random.random()*5
        #print(s)
        r=Rect(x*10, y*10, s, s)
        rects.append(r)
for r in rects:
    r.display(ct)

# %%
plt.figure(figsize=(12,12))
rects= []
for x in range(5):
    for y in range(5):
        for i in range(5):
            s=3+random.random()*6
            r=Rect(x*10, y*10, s, s)
            rects.append(r)
        
for r in rects:
    r.display(ct)

# %%
plt.figure(figsize=(12,12))
plt.axis("off")
rects= []
for x in range(5):
    for y in range(5):
        for i in range(5):
            s=3+random.random()*6
            ox=3*random.random()
            oy=3*random.random()
            r=Rect(x*10 + ox, y*10 + oy, s, s)
            rects.append(r)
        
for r in rects:
    r.display(ct)

# %%
plt.figure(figsize=(12,12))
plt.axis("off")
rects= []
for x in range(5):
    for y in range(5):
        for i in range(5):
            s=3+random.random()*6
            ox=3*random.random()-1.5
            oy=3*random.random()-1.5
            r=Rect(x*10 + ox, y*10 + oy, s, s)
            rects.append(r)
        
for r in rects:
    r.display(ct)

# %%
plt.figure(figsize=(12,12))
plt.axis("off")
rects= []
for x in range(5):
    for y in range(5):
        for i in range(5):
            s=3+random.random()*6
            ox=3*random.random()-1.5
            oy=3*random.random()-1.5
            r=Rect(x*10 + ox, y*10 + oy, s, s)
            rects.append(r)
        
for r in rects:
    ct = [random.random(), 0.5, 0.6, 0.4]
    r.display(ct)

# %%
import matplotlib.pyplot as plt
import math

class Rect(object):
    def __init__(self, cx, cy, width, height,res, angle):
        self.cx = cx
        self.cy = cy
        self.width = width
        self.height = height
        w2 = self.width/2.0
        h2 = self.height/2.0
        
        #list of x and list of y coordinates
        #create empty lists
        
        self.x= []
        self.y=[]
        
        a=2*math.pi/res
        
        for i in range(res):
                self.x.append(cx+math.cos(i*a+angle)*w2)
                self.y.append(cy+math.sin(i*a+angle)*h2)
        # i goes thru the loop but doesnt go back to the strat value
        #to close the shape append and assign i to 0(first value)
            
        
    def display (self, colorv):
        plt.axis("equal")
        plt.plot(self.x, self.y, c="k", linewidth=0)
        plt.fill(self.x, self.y, c=colorv, linewidth=0)
        
     
        
# rectangle define : center pt, width and height

    
plt.figure(figsize=(12,12))
plt.axis("off")
rects= []
# to add more shapes in same layer create more than for loop and append to same list (change the name)

for x in range(1):
    for y in range(2):
        for i in range(3):
            s=3+random.random()*6
            ox=3*random.random()-1.5
            oy=3*random.random()-1.5
            r=Rect(x*10 + ox, y*10 + oy, s, s,3, s)
            rects.append(r)
            
for x in range(4):
    for y in range(5):
        for i in range(6):
            s=3+random.random()*6
            s2=4+random.random()*7
            ox=3*random.random()-3
            oy=3*random.random()-3
            r1=Rect(x*10 + ox, y*10 + oy, s, s2,8, s)
            rects.append(r1)
        
for r in rects:
    ct = [random.random(), 0.4, 0.6, 0.4]
    r.display(ct)

# %%
import matplotlib.pyplot as plt
import math

class Rect(object):
    def __init__(self, cx, cy, width, height,res, angle):
        self.cx = cx
        self.cy = cy
        self.width = width
        self.height = height
        w2 = self.width/2.0
        h2 = self.height/2.0
        
        #list of x and list of y coordinates
        #create empty lists
        
        self.x= []
        self.y=[]
        
        a=2*math.pi/res
        
        for i in range(res):
            if res < 5:
                self.x.append(cx+math.cos(i*a+angle)*w2)
                self.y.append(cy+math.sin(i*a+angle)*h2)
        # i goes thru the loop but doesnt go back to the strat value
        #to close the shape append and assign i to 0(first value)
            else:  
                self.x.append(cx+math.cos(i*a+angle)*w2)
                self.y.append(cy+math.sin(i*a+angle)*h2)
                
                self.x.append(cx+math.cos(0*a+angle)*w2)
                self.y.append(cy+math.sin(0*a+angle)*h2)
            
        
    def display (self, colorv):
        plt.axis("equal")
        plt.plot(self.x, self.y, c="k", linewidth=1)
        plt.fill(self.x, self.y, c=colorv, linewidth=1)
        
     
        
# rectangle define : center pt, width and height

    
plt.figure(figsize=(12,12))
plt.axis("off")
rects= []
# to add more shapes in same layer create more than for loop and append to same list (change the name)

for x in range(5):
    for y in range(5):
        for i in range(5):
            s=3+random.random()*6
            ox=3*random.random()-1.5
            oy=3*random.random()-1.5
            r=Rect(x*10 + ox, y*10 + oy, s, s,3, s)
            rects.append(r)
            
for x in range(8):
    for y in range(8):
            s=3+random.random()*6
            ox=3*random.random()-1.5
            oy=3*random.random()-1.5
            r1=Rect(x*10 + ox, y*10 + oy, s,s, 6, s)
            rects.append(r1)
        
for r in rects:
    ct = [random.random(), 0.4, 0.6, 0.4]
    r.display(ct)

# %%
    
plt.figure(figsize=(12,12))
plt.axis("off")
rects= []
# to add more shapes in same layer create more than for loop and append to same list (change the name)

for x in range(1):
        for i in range(3):
            s=3+random.random()*6
            ox=3*random.random()-1.5
            oy=3*random.random()-1.5
            r=Rect(x*10 + ox, y*10 + oy, s, s,4, s)
            rects.append(r)
            
for x in range(5):
        for i in range(5):
            s=3+random.random()*6
            ox=3*random.random()-1.5
            oy=3*random.random()-1.5
            r1=Rect(x*10 + ox, y*10 + oy, s, s,4, s)
            rects.append(r1)
        
for r in rects:
    ct = [random.random(), 0.4, 0.6, 0.4]
    r.display(ct)

# %%
import matplotlib.pyplot as plt
import math

class Rect(object):
    def __init__(self, cx, cy, width, height,res,c, angle):
        self.cx = cx
        self.cy = cy
        self.width = width
        self.height = height
        w2 = self.width/2.0
        h2 = self.height/2.0
        self.c=c
        
        #list of x and list of y coordinates
        #create empty lists
        
        self.x= []
        self.y=[] 
        a=2*math.pi/res 
        for i in range(res):
                self.x.append(cx+math.cos(i*a+angle)*w2)
                self.y.append(cy+math.sin(i*a+angle)*h2)
        # i goes thru the loop but doesnt go back to the strat value
        #to close the shape append and assign i to 0(first value)
    
        
    def display (self, colorv):
        
        plt.axis("equal")
        plt.plot(self.x, self.y, c="k", linewidth=0)
        plt.fill(self.x, self.y, c=colorv, linewidth=2 )
           
            
# rectangle define : center pt, width and height

    
plt.figure(figsize=(12,12))
plt.axis("off")
rects= []
c=[0.7,1,1]

for x in range(8):
    for y in range(8):
            s=3+random.random()*6
            ox=3*random.random()-1.5
            oy=3*random.random()-1.5
            r1=Rect(x*10 , y*6 , s,s, 2,c, s)
            rects.append(r1)
            
for x in range(8):
    for y in range(8):
            s=3+random.random()*6
            s2=4+random.random()*10
            ox=3*random.random()-1.5
            oy=3*random.random()-1.5
            r1=Rect(x*10 , y*9 , s,s, 2,c, s2)
            rects.append(r1)
for x in range(8):
    for y in range(10):
            s=3+random.random()*6
            ox=3*random.random()-1.5
            oy=3*random.random()-1.5
            r1=Rect(x*10 , y*15 , s,s, 2,c, s)
            rects.append(r1)
            
        

for r in rects:
    ct = [random.random(), 0.7, 0.8, 1]
    r.display(ct)

# %%
import matplotlib.pyplot as plt
import math

class Rect(object):
    def __init__(self, cx, cy, width, height,res,c, angle):
        self.cx = cx
        self.cy = cy
        self.width = width
        self.height = height
        w2 = self.width/2.0
        h2 = self.height/2.0
        self.c=c
        
        self.x= []
        self.y=[] 
        a=2*math.pi/res 
        for i in range(res):
                self.x.append(cx+math.cos(i*a+angle)*w2)
                self.y.append(cy+math.sin(i*a+angle)*h2)
        
    
    def display (self, colorv, lwlist):
        
        plt.axis("equal")
        plt.plot(self.x, self.y, c="k", linewidth=0)
        plt.fill(self.x, self.y, c=colorv, linewidth=lwlist )
           
            
# rectangle define : center pt, width and height
   
plt.figure(figsize=(12,12))
plt.axis("off")
rects= []
c=[0.7,1,1]

for x in range(8):
    for y in range(10):
            s=3+random.random()*6
            ox=3*random.random()-1.5
            oy=3*random.random()-1.5
            r1=Rect(x*10 , y*15 , s,s, 2,c, s)
            rects.append(r1)
            
for x in range(8):
    for y in range(8):
            s=3+random.random()*6
            s2=4+random.random()*10
            ox=3*random.random()-1.5
            oy=3*random.random()-1.5
            r1=Rect(x*10 , y*9 , s,s, 2,c, s2)
            rects.append(r1)

for x in range(8):
    for y in range(8):
            s=3+random.random()*6
            ox=3*random.random()-1.5
            oy=3*random.random()-1.5
            r1=Rect(x*10 , y*6 , s,s, 2,c, s)
            rects.append(r1)
                      
        

for i,r in enumerate (rects):
    ct = [random.random(), 0.7, 0.8, 0.8]
    lwlist = i/50
    r.display(ct, lwlist)

# %% [markdown]
# #
