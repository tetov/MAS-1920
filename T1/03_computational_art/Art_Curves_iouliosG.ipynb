# %%
import random
import matplotlib.pyplot as plt

# Curve Formula:
# y = a*x**2 + b*x + c

class Curve:
    def __init__(self, a, b, c):
        self.a = a
        self.b = b
        self.c = c
        self.x = []
        self.y = []
        for i in range(-10,10):
            xv = i
            self.x.append(xv)
            yv = ((self.a * (i**2))/10 + (self.b * i) + (self.c))/10
            self.y.append(yv)
        for i in range(-10,10):
            xv = i
            self.x.append(xv)
            yv = ((self.a * (i**2))/10 + (self.b * i) + (self.c))/10
            self.y.append(-yv)    
      
        
        
        #list of x and list of y

        
    
def display(lines):
    plt.figure(figsize=(12,12))
    plt.axis("equal")
    for line in lines:
        plt.plot(line.x, line.y, c="k", linewidth = 0.1)
        

    
    
        
        
        #plt.fill(self.x, self.y, c=cv, linewidth = 1)

# %%
d11 = Curve2(1.9,0.6,0.1 )
d11.display()

# %%
for i in range(100):
    d1 = Curve(0.2,(i)/10,0.1 )
    d1.display()

# %%
for m in range(100):
    d2 = Curve((0.2+m)/10,0.2,0.1 )
    d2.display()

# %%
for i in range(0,50):
    d5 = Curve(0.2,(i)/10,0.1 )
    d5.display()

# %%
class Curve2:
    def __init__(self, a, b, c):
        self.a = a
        self.b = b
        self.c = c
        self.x = []
        self.y = []
        for i in range(-10,10):
            xv = i
            self.x.append(xv)
            yv = ((self.a * (i**2))/10 + (self.b * i) + (self.c))/10
            self.y.append(-yv)    
      
        
        
        #list of x and list of y

        
    
    def display(self):
        plt.axis("equal")
        plt.plot(self.x, self.y, c="k", linewidth = 0.1)
        #plt.fill(self.x, self.y, c=cv, linewidth = 1)

# %%
for s in range(10,80):
    d3 = Curve2(0.2,(s)/10,0.1 )
    d3.display()

# %%
for s in range(-50,100):
    d3 = Curve2((s)/10,(10+s)/10,(10+s)/10 )
    d3.display()

# %%
listoflines4=[]
class Painting:
    for m in range(100):
        d2 = Curve((0.2+m)/10,0.2,0.1 )
        listoflines4.append(d2)
    for i in range(100):
        d5 = Curve(0.2,(i)/10,0.1 )
        listoflines4.append(d5)
        
display(listoflines4)

# %%
listoflines3=[]

class Painting2:
    for i in range(0,50):
        d5 = Curve(0.2,(i)/10,0.1 )
        listoflines3.append(d5)
    for i in range(100):
        d1 = Curve(0.2,(i)/10,0.1 )
        listoflines3.append(d1)
        
display(listoflines3)

# %%
class Painting3:
    for m in range(100):
        d2 = Curve((0.2+m)/10,0.2,random.random() )
        d2.display()
    for i in range(100):
        d5 = Curve(0.2,(i)/10,random.random() )
        d5.display()

# %%
listoflines=[]
for m in range(100):
    d7 = Curve((0.2+m)/10,random.random(),random.random() )
    listoflines.append(d7)

display(listoflines)

# %%
listoflines2=[]

class Painting3:
    for m in range(100):
        d2 = Curve((0.2+m)/10,0.2,random.random() )
        listoflines2.append(d2)
    for i in range(100):
        d5 = Curve(0.2,(i)/10,random.random() )
        listoflines2.append(d5) 
        
display(listoflines2)
